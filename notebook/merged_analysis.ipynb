# %%
import pandas as pd
df = pd.read_csv("../data/merged/merged.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4181370 entries, 0 to 4181369
# Data columns (total 16 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   owner            str
#  1   name             str
#  2   stars            int64
#  3   forks            int64
#  4   watchers         int64
#  5   languageCount    int64
#  6   description      str
#  7   primaryLanguage  str
#  8   createdAt        str
#  9   pushedAt         str
#  10  languages        str
#  11  topics           str
#  12  isFork           bool
#  13  isArchived       bool
#  14  repo_age_days    float64
#  15  combined_text    str
# dtypes: bool(2), float64(1), int64(4), str(9)
# memory usage: 454.6 MB

# %%
df.duplicated(subset=["owner","name"]).sum()
# Out:
# np.int64(4282)

# %%
df.duplicated(subset=["owner", "name", "combined_text"]).sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates(
    subset=["owner", "name", "combined_text"]
)

# %%
df.shape
# Out:
# (4177100, 16)
