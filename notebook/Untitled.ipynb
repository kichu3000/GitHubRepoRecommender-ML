# %%
path = '../data/repo_metadata.json'
with open(path, "r", encoding="utf-8") as f:
    for i in range(5):
        print(f.readline())

# %%
# !pip install ijson
# Out:
# Collecting ijson
#   Downloading ijson-3.5.1-cp314-cp314-win_amd64.whl.metadata (24 kB)
# Downloading ijson-3.5.1-cp314-cp314-win_amd64.whl (55 kB)
# Installing collected packages: ijson
# Successfully installed ijson-3.5.1

# %%
import ijson
with open(path, "rb") as f:
    first_repo = next(ijson.items(f, "item"))

first_repo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import ijson
# ----> 2 with open(path, "rb") as f:
#       3     first_repo = next(ijson.items(f, "item"))
#       4
#       5 first_repo
#
# NameError: name 'path' is not defined
