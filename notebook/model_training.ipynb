# %%
import joblib

# %%
vector_data = joblib.load('../data/models/tfidf_vectorizer.pkl')

# %%
vector_data.dtype
# Out:
# numpy.float64

# %%
type(vector_data)
# Out:
# sklearn.feature_extraction.text.TfidfVectorizer
