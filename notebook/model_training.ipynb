# %%
import joblib

# %%
vector_data = joblib.load('../data/models/X_sample.pkl')

# %%
vector_data.dtype
# Out:
# dtype('float64')

# %%
type(vector_data)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
vector_data.shape
# Out:
# (80000, 115158)

# %%
vector_data.nnz
# Out:
# 976047
